# %% [markdown]
# # Section 5. Linux / WSL 특강
#
# 이 섹션은 Section 1-4 실습을 끝낸 뒤 보면 됩니다. 목표는 학생들이 터미널에서 길을 잃지 않도록 최소한의 Linux 감각을 갖추는 것입니다.
#
# 이 노트북은 OpenAI API를 호출하지 않습니다. sudo나 apt 설치가 필요한 작업은 혼자 진행하지 말고 스태프에게 요청합니다.

# %% [markdown]
# ## 꼭 알아야 할 명령
#
# ```bash
# pwd        # 지금 내가 있는 폴더
# ls         # 현재 폴더의 파일 목록
# cd 폴더명   # 폴더 이동
# cd ..      # 한 단계 위로 이동
# mkdir 이름 # 새 폴더 만들기
# ```
#
# 수업 자료에서는 대부분 루트 폴더에서 명령을 실행합니다. 루트 폴더에는 `START_HERE.md`, `requirements.txt`, `notebooks/`가 보입니다.

# %%
from pathlib import Path

print("현재 폴더:", Path.cwd())
print("현재 폴더 파일 일부:")
for path in sorted(Path.cwd().iterdir())[:20]:
    print("-", path.name)

# %% [markdown]
# ## uv와 Python의 관계
#
# 이번 과정에서는 Python library 설치와 실행을 uv로 관리합니다.
#
# ```bash
# uv --version
# uv run --python 3.11 python --version
# uv run --python 3.11 --with-requirements requirements.txt --with notebook jupyter notebook notebooks
# ```
#
# 전역 `python` 명령이 안 된다고 바로 python.org나 apt로 Python을 다시 설치하지 않습니다. 먼저 `uv run --python 3.11 python --version`이 되는지 확인합니다.

# %% [markdown]
# ## sudo / apt가 필요한 경우
#
# 아래 같은 작업은 시스템 설정을 바꾸므로 스태프에게 먼저 요청합니다.
#
# ```bash
# sudo apt update
# sudo apt install ...
# ```
#
# Python library는 sudo/apt가 아니라 uv와 `requirements.txt`로 설치합니다.

# %% [markdown]
# ## 결과 확인
#
# - `pwd`, `ls`, `cd ..`의 의미를 설명할 수 있습니다.
# - 수업 자료 루트 폴더에 무엇이 있어야 하는지 알고 있습니다.
# - Python library는 uv로 설치한다는 원칙을 알고 있습니다.
# - sudo/apt가 필요하면 혼자 처리하지 않고 명령과 이유를 스태프에게 확인받습니다.
